# %%
import numpy as np   # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('netflix_titles_nov_2019.csv')
df
# Out:
#        show_id                                title
# 0     81193313                            Chocolate  \
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director
# 0                            NaN  \
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# 5834                Ole Bornedal
# 5835                         NaN
# 5836        Sorin Dan Mihalcescu
#
#                                                    cast
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  \
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4     Abigail Oliver, Andrea Libman, Briana Buckmast...
# ...                                                 ...
# 5832  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...
# 5833  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...
# 5834  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...
# 5835                                                NaN
# 5836  Barbara King, Shaana Diya, John Krisiukenas, Y...
#
#                        country         date_added  release_year rating
# 0                  South Korea  November 30, 2019          2019  TV-14  \
# 1                          NaN  November 30, 2019          2019   TV-G
# 2                        India  November 30, 2019          2019  TV-14
# 3     France, Senegal, Belgium  November 29, 2019          2019  TV-14
# 4       Canada, United Kingdom                NaN          2019   TV-Y
# ...                        ...                ...           ...    ...
# 5832             United States   November 1, 2010          1987     NR
# 5833             United States  November 18, 2009          2009  TV-14
# 5834                   Denmark        May 5, 2009          2007     NR
# 5835             United States   February 4, 2008          2007  TV-MA
# 5836             United States    January 1, 2008          2006     NR
#
#        duration                                          listed_in
# 0      1 Season  International TV Shows, Korean TV Shows, Roman...  \
# 1        67 min                Documentaries, International Movies
# 2       135 min             Comedies, Dramas, International Movies
# 3       106 min   Dramas, Independent Movies, International Movies
# 4     2 Seasons                                           Kids' TV
# ...         ...                                                ...
# 5832     84 min                         Cult Movies, Horror Movies
# 5833     29 min                                      Horror Movies
# 5834    104 min                       Dramas, International Movies
# 5835   1 Season                       Stand-Up Comedy & Talk Shows
# 5836     81 min              Dramas, Independent Movies, Thrillers
#
#                                             description     type
# 0     Brought together by meaningful meals in the pa...  TV Show
# 1     From Sierra de las Minas to Esquipulas, explor...    Movie
# 2     A goofy copywriter unwittingly convinces the I...    Movie
# 3     Arranged to marry a rich man, young Ada is cru...    Movie
# 4     Lovable pug Chip starts kindergarten, makes ne...  TV Show
# ...                                                 ...      ...
# 5832  This collection cherry-picks trailers, forgott...    Movie
# 5833  After committing suicide, a washed-up rocker r...    Movie
# 5834  When he causes a car accident that leaves a yo...    Movie
# 5835  In each episode, four celebrities join host Jo...  TV Show
# 5836  While covering a story in New York City, a Sea...    Movie
#
# [5837 rows x 12 columns]

# %%
def data_inv(df):
    print('Netflix Shows and Movies: ',df.shape[0])
    print('Dataset Variables: ',df.shape[1])
    print('-'*10)
    print('Dataset Coulmns: \n')
    print(df.columns)
    print('-'*10)
    print("Data-type of each columns: \n")
    print(df.dtypes)
    print('-'*10)
    print('missing rows in each column: \n')
    c=df.isnull().sum()
    print(c[c>0])
data_inv(df)
# Out:
# Netflix Shows and Movies:  5837
# Dataset Variables:  12
# ----------
# Dataset Coulmns:
#
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')
# ----------
# Data-type of each columns:
#
# show_id          int64
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# type            object
# dtype: object
# ----------
# missing rows in each column:
#
# director      1901
# cast           556
# country        427
# date_added     642
# rating          10
# dtype: int64

# %%
dups=df.duplicated(['title','country','type','release_year'])
df[dups]
# Out:
#        show_id      title         director
# 1134  80175351  Kakegurui              NaN  \
# 1741  81072516     Sarkar  A.R. Murugadoss
#
#                                                    cast country
# 1134  Saori Hayami, Minami Tanaka, Tatsuya Tokutake,...   Japan  \
# 1741  Vijay, Varalakshmi Sarathkumar, Keerthi Suresh...   India
#
#          date_added  release_year rating   duration
# 1134            NaN          2019  TV-14  2 Seasons  \
# 1741  March 2, 2019          2018  TV-MA    162 min
#
#                                               listed_in
# 1134  Anime Series, International TV Shows, TV Thril...  \
# 1741   Action & Adventure, Dramas, International Movies
#
#                                             description     type
# 1134  High roller Yumeko Jabami plans to clean house...  TV Show
# 1741  A ruthless businessman’s mission to expose ele...    Movie

# %%
df=df.drop_duplicates(['title','country','type','release_year'])

# %%
df=df.drop('show_id',axis=1)

# %%
df.cast = df.cast.replace(np.nan,"Unknown")
def cast_counter(cast):
    if cast == "Unknown":
        return 0
    else:
        lst = cast.split(",")
        return len(lst)
    
df["NUmber_of_cast"]=df.cast.apply(cast_counter)
df.cast=df.cast.replace('Unknown',np.nan)

# %%
df
# Out:
#                                     title                    director
# 0                               Chocolate                         NaN  \
# 1     Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2                         The Zoya Factor             Abhishek Sharma
# 3                               Atlantics                   Mati Diop
# 4                         Chip and Potato                         NaN
# ...                                   ...                         ...
# 5832          Mad Ron's Prevues from Hell                  Jim Monaco
# 5833                             Splatter                   Joe Dante
# 5834              Just Another Love Story                Ole Bornedal
# 5835                      Dinner for Five                         NaN
# 5836                 To and From New York        Sorin Dan Mihalcescu
#
#                                                    cast
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  \
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4     Abigail Oliver, Andrea Libman, Briana Buckmast...
# ...                                                 ...
# 5832  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...
# 5833  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...
# 5834  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...
# 5835                                                NaN
# 5836  Barbara King, Shaana Diya, John Krisiukenas, Y...
#
#                        country         date_added  release_year rating
# 0                  South Korea  November 30, 2019          2019  TV-14  \
# 1                          NaN  November 30, 2019          2019   TV-G
# 2                        India  November 30, 2019          2019  TV-14
# 3     France, Senegal, Belgium  November 29, 2019          2019  TV-14
# 4       Canada, United Kingdom                NaN          2019   TV-Y
# ...                        ...                ...           ...    ...
# 5832             United States   November 1, 2010          1987     NR
# 5833             United States  November 18, 2009          2009  TV-14
# 5834                   Denmark        May 5, 2009          2007     NR
# 5835             United States   February 4, 2008          2007  TV-MA
# 5836             United States    January 1, 2008          2006     NR
#
#        duration                                          listed_in
# 0      1 Season  International TV Shows, Korean TV Shows, Roman...  \
# 1        67 min                Documentaries, International Movies
# 2       135 min             Comedies, Dramas, International Movies
# 3       106 min   Dramas, Independent Movies, International Movies
# 4     2 Seasons                                           Kids' TV
# ...         ...                                                ...
# 5832     84 min                         Cult Movies, Horror Movies
# 5833     29 min                                      Horror Movies
# 5834    104 min                       Dramas, International Movies
# 5835   1 Season                       Stand-Up Comedy & Talk Shows
# 5836     81 min              Dramas, Independent Movies, Thrillers
#
#                                             description     type
# 0     Brought together by meaningful meals in the pa...  TV Show  \
# 1     From Sierra de las Minas to Esquipulas, explor...    Movie
# 2     A goofy copywriter unwittingly convinces the I...    Movie
# 3     Arranged to marry a rich man, young Ada is cru...    Movie
# 4     Lovable pug Chip starts kindergarten, makes ne...  TV Show
# ...                                                 ...      ...
# 5832  This collection cherry-picks trailers, forgott...    Movie
# 5833  After committing suicide, a washed-up rocker r...    Movie
# 5834  When he causes a car accident that leaves a yo...    Movie
# 5835  In each episode, four celebrities join host Jo...  TV Show
# 5836  While covering a story in New York City, a Sea...    Movie
#
#       NUmber_of_cast
# 0                  8
# 1                  1
# 2                  8
# 3                  9
# 4                 10
# ...              ...
# 5832              10
# 5833               6
# 5834              12
# 5835               0
# 5836               6
#
# [5835 rows x 12 columns]

# %%
df=df.reset_index()
df
# Out:
#       index                                title                    director
# 0         0                            Chocolate                         NaN  \
# 1         1  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2         2                      The Zoya Factor             Abhishek Sharma
# 3         3                            Atlantics                   Mati Diop
# 4         4                      Chip and Potato                         NaN
# ...     ...                                  ...                         ...
# 5830   5832          Mad Ron's Prevues from Hell                  Jim Monaco
# 5831   5833                             Splatter                   Joe Dante
# 5832   5834              Just Another Love Story                Ole Bornedal
# 5833   5835                      Dinner for Five                         NaN
# 5834   5836                 To and From New York        Sorin Dan Mihalcescu
#
#                                                    cast
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  \
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4     Abigail Oliver, Andrea Libman, Briana Buckmast...
# ...                                                 ...
# 5830  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...
# 5831  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...
# 5832  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...
# 5833                                                NaN
# 5834  Barbara King, Shaana Diya, John Krisiukenas, Y...
#
#                        country         date_added  release_year rating
# 0                  South Korea  November 30, 2019          2019  TV-14  \
# 1                          NaN  November 30, 2019          2019   TV-G
# 2                        India  November 30, 2019          2019  TV-14
# 3     France, Senegal, Belgium  November 29, 2019          2019  TV-14
# 4       Canada, United Kingdom                NaN          2019   TV-Y
# ...                        ...                ...           ...    ...
# 5830             United States   November 1, 2010          1987     NR
# 5831             United States  November 18, 2009          2009  TV-14
# 5832                   Denmark        May 5, 2009          2007     NR
# 5833             United States   February 4, 2008          2007  TV-MA
# 5834             United States    January 1, 2008          2006     NR
#
#        duration                                          listed_in
# 0      1 Season  International TV Shows, Korean TV Shows, Roman...  \
# 1        67 min                Documentaries, International Movies
# 2       135 min             Comedies, Dramas, International Movies
# 3       106 min   Dramas, Independent Movies, International Movies
# 4     2 Seasons                                           Kids' TV
# ...         ...                                                ...
# 5830     84 min                         Cult Movies, Horror Movies
# 5831     29 min                                      Horror Movies
# 5832    104 min                       Dramas, International Movies
# 5833   1 Season                       Stand-Up Comedy & Talk Shows
# 5834     81 min              Dramas, Independent Movies, Thrillers
#
#                                             description     type
# 0     Brought together by meaningful meals in the pa...  TV Show  \
# 1     From Sierra de las Minas to Esquipulas, explor...    Movie
# 2     A goofy copywriter unwittingly convinces the I...    Movie
# 3     Arranged to marry a rich man, young Ada is cru...    Movie
# 4     Lovable pug Chip starts kindergarten, makes ne...  TV Show
# ...                                                 ...      ...
# 5830  This collection cherry-picks trailers, forgott...    Movie
# 5831  After committing suicide, a washed-up rocker r...    Movie
# 5832  When he causes a car accident that leaves a yo...    Movie
# 5833  In each episode, four celebrities join host Jo...  TV Show
# 5834  While covering a story in New York City, a Sea...    Movie
#
#       NUmber_of_cast
# 0                  8
# 1                  1
# 2                  8
# 3                  9
# 4                 10
# ...              ...
# 5830              10
# 5831               6
# 5832              12
# 5833               0
# 5834               6
#
# [5835 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5835 entries, 0 to 5834
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           5835 non-null   int64
#  1   title           5835 non-null   object
#  2   director        3935 non-null   object
#  3   cast            5279 non-null   object
#  4   country         5408 non-null   object
#  5   date_added      5194 non-null   object
#  6   release_year    5835 non-null   int64
#  7   rating          5825 non-null   object
#  8   duration        5835 non-null   object
#  9   listed_in       5835 non-null   object
#  10  description     5835 non-null   object
#  11  type            5835 non-null   object
#  12  NUmber_of_cast  5835 non-null   int64
# dtypes: int64(3), object(10)
# memory usage: 592.7+ KB

# %%
df.isnull().sum()
# Out:
# index                0
# title                0
# director          1900
# cast               556
# country            427
# date_added         641
# release_year         0
# rating              10
# duration             0
# listed_in            0
# description          0
# type                 0
# NUmber_of_cast       0
# dtype: int64

# %%
df['rating'] = df['rating'].fillna(df['rating'].mode()[0])
df['rating'].sample(10)
# Out:
# 2345    TV-Y7-FV
# 2423       TV-14
# 5519          NR
# 5602       TV-14
# 560        TV-MA
# 814        TV-PG
# 4961       TV-14
# 3842       TV-14
# 4124       TV-MA
# 4559       TV-PG
# Name: rating, dtype: object

# %%
df['date_added'] = df['date_added']
